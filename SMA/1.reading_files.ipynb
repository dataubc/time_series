# %%
### Reading the data

# %%
file = open('data/sma.txt','r') # open file
names = [] # name of the stock
stocks = [] # list of lists for the prices for each stock
for line in file:
    data = line.strip().split()
    stocks.append(data[0]) # this is the part which includes the price name
    prices.append([float(i) for i in data[1:]]) # the rest of the line include the prices

# %%
prices[0][1:10]
# Out:
# [122.26, 123.94, 122.11, 120.58, 127.86, 123.64, 118.37, 124.3, 126.5]

# %%
len(prices)
# Out:
# 10

# %%
import pandas as pd
import matplotlib.pyplot as plt

def test_run():
    # plotting stocks prices for all stocks a data set
    for i in range(len(prices)):
        plt.plot(prices[i])
        plt.ylabel(stocks[i])
        plt.show() # if we don't include this then all plots will be at the same plot.


if __name__ == "__main__":
    test_run()
